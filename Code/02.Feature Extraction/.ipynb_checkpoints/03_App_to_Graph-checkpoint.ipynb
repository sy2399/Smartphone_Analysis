# %%
from IPython.display import Image

import pandas as pd
import numpy as np
from pprint import pprint



import os, sys
file_dir = '/Users/imsoyoung/Soyoung/Ajou/Project/DigitalPhenotype/DigitalPhenotype_overall/Code/Util'
sys.path.append(os.path.dirname(os.path.abspath
                                (os.path.abspath(file_dir))))

import Util.Utility as util


# %matplotlib inline
import matplotlib.pylab as plt
import datetime 
import seaborn as sns
plt.rcParams["figure.figsize"] = (15,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = True 

# !pip install networkx
import networkx as nx

# %%
Image("../../img/DP_Graph.png")

# %%
app = pd.read_csv('../01.Preprocess/result/A_categorized.csv')
util.toDatetime(app, ['date'], '%Y%m%d')
app.head(3)
# Out:
#    Unnamed: 0  _id                           uid       date  \
# 0           2    3  otfKOMf7VUaB5lxUARO0HNusxPB2 2018-12-03
# 1          17   20  otfKOMf7VUaB5lxUARO0HNusxPB2 2018-12-03
# 2          19   22  otfKOMf7VUaB5lxUARO0HNusxPB2 2018-12-03
#
#                  stime                etime packageName  total  isInUsable  \
# 0  2018-12-03 00:11:59  2018-12-03 00:12:10        캐시워크     11        True
# 1  2018-12-03 00:13:21  2018-12-03 00:13:24        카카오톡      3        True
# 2  2018-12-03 00:13:32  2018-12-03 00:13:33        카카오톡      1        True
#
#          packageFullName          category
# 0  com.cashwalk.cashwalk  Health & Fitness
# 1         com.kakao.talk     Communication
# 2         com.kakao.talk     Communication

# %% [markdown]
# # App Category 전처리
#
# - LDA 분석시, Communication 의 비율이 너무 큼
#     - Communication --> Chatting / SNS 분리

# %%
app['category'] = app.apply(lambda row : 'Chat' if row['packageName'] == '카카오톡' else row['category'], axis=1)
print(set(app['category']))
count = app.groupby('category')['total'].count().reset_index()

count
# Out:
# {'Background', 'Music', 'Health & Fitness', 'Chat', 'Productivity', 'Photography', 'Food & Drink', 'Business', 'Shopping', 'Travel & Local', 'Finance', 'Comics', 'Entertainment', 'Communication', 'Lifestyle', 'Education', 'Books & Reference'}
#              category  total
# 0          Background    432
# 1   Books & Reference      7
# 2            Business      6
# 3                Chat   1584
# 4              Comics    139
# 5       Communication   1020
# 6           Education    104
# 7       Entertainment     76
# 8             Finance     65
# 9        Food & Drink    145
# 10   Health & Fitness   1602
# 11          Lifestyle      4
# 12              Music    124
# 13        Photography    104
# 14       Productivity     76
# 15           Shopping     75
# 16     Travel & Local     36

# %%
print(set(app[app['category']=='Communication']['packageName']))
app[app['category']=='Communication'].groupby('packageName')['total'].count()
# Out:
# {'Chrome', 'Gmail', '에브리타임', '아주톡톡', 'Facebook', 'Messenger', 'NAVER', 'Instagram', 'Between', 'BAND'}
# packageName
# BAND           8
# Between        1
# Chrome        54
# Facebook     572
# Gmail         33
# Instagram     13
# Messenger      5
# NAVER        171
# 아주톡톡           1
# 에브리타임        162
# Name: total, dtype: int64

# %%
app_sub = app[~app['packageName'].isin(['카카오톡', 'Facebook'])]
print(app.shape, app_sub.shape)
# Out:
# (5599, 11) (3443, 11)

# %%
app_sub = app[~app['category'].isin(['Health & Fitness', 'Background'])]

# %% [markdown]
# # Count Transition

# %%
app_sub['next_category'] = app_sub['category'].shift(-1)
app_sub['transition'] = app_sub.apply(lambda row: True if row['category']!= row['next_category'] else False, axis=1)
# Out:
# /Users/imsoyoung/opt/anaconda3/envs/tensorflow1/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/imsoyoung/opt/anaconda3/envs/tensorflow1/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def getTransOfCat(df, current_cat):
    cat_counts = {}
    
    for cat in cat_list:
        if cat != current_cat:
            cat_counts[cat] = 0
            df_cat = df[df['next_category'] == cat]['category'].count()
            cat_counts[cat] += df_cat
        
    return cat_counts

    
cat_list = list(set(app_sub['category']))

trans_df = pd.DataFrame(index = cat_list, columns = cat_list )
trans_df = trans_df.fillna(0)

trans_dict = {}

for cat in cat_list:
    for day in list(set(app_sub['date'])):
        tmp_df = pd.DataFrame(index = cat_list, columns = cat_list )

        tmp = app_sub[app_sub['date']==day]
        trans = tmp[(tmp['category']==cat) & (tmp['transition']==True)]

        cat_counts = getTransOfCat(trans, cat)

#         print(cat_counts)

        for key, value in cat_counts.items():
#             print(cat, key, value[0])
            tmp_df.loc[(cat), (key)] = value
    
        trans_df = pd.concat([trans_df, tmp_df])

# %%
trans_df = trans_df.head()
print(trans_df.shape)
trans_df.head()
# Out:
# (5, 15)
#              Music Photography Chat Productivity Food & Drink Business  \
# Music            0           0    0            0            0        0
# Photography      0           0    0            0            0        0
# Chat             0           0    0            0            0        0
# Productivity     0           0    0            0            0        0
# Food & Drink     0           0    0            0            0        0
#
#              Shopping Travel & Local Finance Comics Entertainment  \
# Music               0              0       0      0             0
# Photography         0              0       0      0             0
# Chat                0              0       0      0             0
# Productivity        0              0       0      0             0
# Food & Drink        0              0       0      0             0
#
#              Communication Lifestyle Education Books & Reference
# Music                    0         0         0                 0
# Photography              0         0         0                 0
# Chat                     0         0         0                 0
# Productivity             0         0         0                 0
# Food & Drink             0         0         0                 0

# %%
trans_array = trans_df.to_numpy()



G = nx.from_numpy_matrix(trans_array, nodelist = cat_list)
nx.draw(G, with_labels=True)


G = nx.from_numpy_matrix(alignments)
G = nx.maximum_spanning_tree(G)

pos = {}
for i in range(len(G.nodes)):
    pos[i] = np.array([time[i], y[i]])

mst_edges = set(nx.maximum_spanning_tree(G).edges())

weights = [ G[u][v]['weight'] if (not (u, v) in mst_edges) else 8
            for u, v in G.edges() ]

plt.figure()
nx.draw(G, pos, edges=G.edges(), width=10)
plt.ylim([-1, 1])
plt.savefig(namespace + '.svg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-8c18a5389e85> in <module>
#       2
#       3
# ----> 4 G = nx.from_numpy_matrix(trans_array, nodelist = cat_list)
#       5 nx.draw(G, with_labels=True)
#
# TypeError: from_numpy_matrix() got an unexpected keyword argument 'nodelist'
